# %% [markdown]
# # Healthcare utilization and prediction

# %% [markdown]
# the dataset used is Oh Canada dataset from https://synthea.mitre.org/downloads.

# %%
import os
from pyspark.sql import SparkSession
from pyspark.sql.functions import explode, col
from pyspark.sql.types import StructType, StructField, StringType, BooleanType, ArrayType, FloatType

# %%
# Initialize Spark Session
spark = SparkSession.builder \
    .appName("FHIR Data Pipeline") \
    .getOrCreate()

# %%
# Define the schema for the JSON file
schema = StructType([
    StructField("resourceType", StringType(), True),
    StructField("type", StringType(), True),
    StructField("entry", ArrayType(
        StructType([
            StructField("fullUrl", StringType(), True),
            StructField("resource", StructType([
                StructField("resourceType", StringType(), True),
                StructField("id", StringType(), True),
                StructField("text", StructType([
                    StructField("status", StringType(), True),
                    StructField("div", StringType(), True)
                ]), True),
                StructField("extension", ArrayType(
                    StructType([
                        StructField("url", StringType(), True),
                        StructField("valueString", StringType(), True)
                    ])
                ), True),
                StructField("identifier", ArrayType(
                    StructType([
                        StructField("system", StringType(), True),
                        StructField("value", StringType(), True)
                    ])
                ), True),
                StructField("name", ArrayType(
                    StructType([
                        StructField("use", StringType(), True),
                        StructField("family", StringType(), True),
                        StructField("given", ArrayType(StringType()), True),
                        StructField("prefix", ArrayType(StringType()), True)
                    ])
                ), True),
                StructField("telecom", ArrayType(
                    StructType([
                        StructField("system", StringType(), True),
                        StructField("value", StringType(), True),
                        StructField("use", StringType(), True)
                    ])
                ), True),
                StructField("gender", StringType(), True),
                StructField("birthDate", StringType(), True),
                StructField("address", ArrayType(
                    StructType([
                        StructField("extension", ArrayType(
                            StructType([
                                StructField("url", StringType(), True),
                                StructField("extension", ArrayType(
                                    StructType([
                                        StructField("url", StringType(), True),
                                        StructField("valueDecimal", FloatType(), True)
                                    ])
                                ), True)
                            ])
                        ), True),
                        StructField("line", ArrayType(StringType()), True),
                        StructField("city", StringType(), True),
                        StructField("state", StringType(), True),
                        StructField("postalCode", StringType(), True),
                        StructField("country", StringType(), True)
                    ])
                ), True),
                StructField("maritalStatus", StructType([
                    StructField("coding", ArrayType(
                        StructType([
                            StructField("system", StringType(), True),
                            StructField("code", StringType(), True),
                            StructField("display", StringType(), True)
                        ])
                    ), True),
                    StructField("text", StringType(), True)
                ]), True),
                StructField("multipleBirthBoolean", BooleanType(), True),
                StructField("communication", ArrayType(
                    StructType([
                        StructField("language", StructType([
                            StructField("coding", ArrayType(
                                StructType([
                                    StructField("system", StringType(), True),
                                    StructField("code", StringType(), True),
                                    StructField("display", StringType(), True)
                                ])
                            ), True),
                            StructField("text", StringType(), True)
                        ]), True)
                    ])
                ), True)
            ]), True),
            StructField("request", StructType([
                StructField("method", StringType(), True),
                StructField("url", StringType(), True)
            ]), True)
        ])
    ), True)
])

# %%
#Step 1: Read the JSON file
file_path = "data/fhir/Abdul218_Gusikowski974_9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1.json"

df_raw = spark.read.option("multiLine", True).json(file_path)
df_raw.printSchema()
df_raw.head(1)
# Out:
# root
#  |-- entry: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- fullUrl: string (nullable = true)
#  |    |    |-- request: struct (nullable = true)
#  |    |    |    |-- method: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- resource: struct (nullable = true)
#  |    |    |    |-- abatementDateTime: string (nullable = true)
#  |    |    |    |-- address: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- city: string (nullable = true)
#  |    |    |    |    |    |-- country: string (nullable = true)
#  |    |    |    |    |    |-- extension: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- extension: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- valueDecimal: double (nullable = true)
#  |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |-- line: array (nullable = true)
#  |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- postalCode: string (nullable = true)
#  |    |    |    |    |    |-- state: string (nullable = true)
#  |    |    |    |-- authoredOn: string (nullable = true)
#  |    |    |    |-- billablePeriod: struct (nullable = true)
#  |    |    |    |    |-- end: string (nullable = true)
#  |    |    |    |    |-- start: string (nullable = true)
#  |    |    |    |-- birthDate: string (nullable = true)
#  |    |    |    |-- careTeam: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- provider: struct (nullable = true)
#  |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |-- role: struct (nullable = true)
#  |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- sequence: long (nullable = true)
#  |    |    |    |-- category: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- claim: struct (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- class: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- clinicalStatus: struct (nullable = true)
#  |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- code: struct (nullable = true)
#  |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- communication: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- language: struct (nullable = true)
#  |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- component: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- code: struct (nullable = true)
#  |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- valueQuantity: struct (nullable = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |-- unit: string (nullable = true)
#  |    |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |-- contained: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- beneficiary: struct (nullable = true)
#  |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- intent: string (nullable = true)
#  |    |    |    |    |    |-- payor: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |-- performer: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |-- requester: struct (nullable = true)
#  |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |-- resourceType: string (nullable = true)
#  |    |    |    |    |    |-- status: string (nullable = true)
#  |    |    |    |    |    |-- subject: struct (nullable = true)
#  |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |-- type: struct (nullable = true)
#  |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- created: string (nullable = true)
#  |    |    |    |-- deceasedDateTime: string (nullable = true)
#  |    |    |    |-- diagnosis: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- diagnosisReference: struct (nullable = true)
#  |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |-- sequence: long (nullable = true)
#  |    |    |    |    |    |-- type: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- effectiveDateTime: string (nullable = true)
#  |    |    |    |-- encounter: struct (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- extension: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |-- valueAddress: struct (nullable = true)
#  |    |    |    |    |    |    |-- city: string (nullable = true)
#  |    |    |    |    |    |    |-- country: string (nullable = true)
#  |    |    |    |    |    |    |-- state: string (nullable = true)
#  |    |    |    |    |    |-- valueDecimal: double (nullable = true)
#  |    |    |    |    |    |-- valueString: string (nullable = true)
#  |    |    |    |-- gender: string (nullable = true)
#  |    |    |    |-- hospitalization: struct (nullable = true)
#  |    |    |    |    |-- dischargeDisposition: struct (nullable = true)
#  |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- identifier: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- type: struct (nullable = true)
#  |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- insurance: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- coverage: struct (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |-- focal: boolean (nullable = true)
#  |    |    |    |    |    |-- sequence: long (nullable = true)
#  |    |    |    |-- insurer: struct (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |-- intent: string (nullable = true)
#  |    |    |    |-- issued: string (nullable = true)
#  |    |    |    |-- item: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- adjudication: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- amount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- currency: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- value: double (nullable = true)
#  |    |    |    |    |    |    |    |-- category: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- category: struct (nullable = true)
#  |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- diagnosisSequence: array (nullable = true)
#  |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |-- encounter: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |-- informationSequence: array (nullable = true)
#  |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |-- locationCodeableConcept: struct (nullable = true)
#  |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- net: struct (nullable = true)
#  |    |    |    |    |    |    |-- currency: string (nullable = true)
#  |    |    |    |    |    |    |-- value: double (nullable = true)
#  |    |    |    |    |    |-- procedureSequence: array (nullable = true)
#  |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |-- productOrService: struct (nullable = true)
#  |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- sequence: long (nullable = true)
#  |    |    |    |    |    |-- servicedPeriod: struct (nullable = true)
#  |    |    |    |    |    |    |-- end: string (nullable = true)
#  |    |    |    |    |    |    |-- start: string (nullable = true)
#  |    |    |    |-- maritalStatus: struct (nullable = true)
#  |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- medicationCodeableConcept: struct (nullable = true)
#  |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- multipleBirthBoolean: boolean (nullable = true)
#  |    |    |    |-- name: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- family: string (nullable = true)
#  |    |    |    |    |    |-- given: array (nullable = true)
#  |    |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |    |-- use: string (nullable = true)
#  |    |    |    |-- occurrenceDateTime: string (nullable = true)
#  |    |    |    |-- onsetDateTime: string (nullable = true)
#  |    |    |    |-- outcome: string (nullable = true)
#  |    |    |    |-- participant: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- individual: struct (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |-- period: struct (nullable = true)
#  |    |    |    |    |    |    |-- end: string (nullable = true)
#  |    |    |    |    |    |    |-- start: string (nullable = true)
#  |    |    |    |    |    |-- type: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- patient: struct (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- payment: struct (nullable = true)
#  |    |    |    |    |-- amount: struct (nullable = true)
#  |    |    |    |    |    |-- currency: string (nullable = true)
#  |    |    |    |    |    |-- value: double (nullable = true)
#  |    |    |    |-- performedPeriod: struct (nullable = true)
#  |    |    |    |    |-- end: string (nullable = true)
#  |    |    |    |    |-- start: string (nullable = true)
#  |    |    |    |-- period: struct (nullable = true)
#  |    |    |    |    |-- end: string (nullable = true)
#  |    |    |    |    |-- start: string (nullable = true)
#  |    |    |    |-- prescription: struct (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- primarySource: boolean (nullable = true)
#  |    |    |    |-- priority: struct (nullable = true)
#  |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- procedure: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- procedureReference: struct (nullable = true)
#  |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |-- sequence: long (nullable = true)
#  |    |    |    |-- provider: struct (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- reasonCode: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- reasonReference: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- recordedDate: string (nullable = true)
#  |    |    |    |-- referral: struct (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- requester: struct (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- resourceType: string (nullable = true)
#  |    |    |    |-- result: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- serviceProvider: struct (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- status: string (nullable = true)
#  |    |    |    |-- subject: struct (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- supportingInfo: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- category: struct (nullable = true)
#  |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- sequence: long (nullable = true)
#  |    |    |    |    |    |-- valueReference: struct (nullable = true)
#  |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- telecom: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- use: string (nullable = true)
#  |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- text: struct (nullable = true)
#  |    |    |    |    |-- div: string (nullable = true)
#  |    |    |    |    |-- status: string (nullable = true)
#  |    |    |    |-- total: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- use: string (nullable = true)
#  |    |    |    |-- vaccineCode: struct (nullable = true)
#  |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- valueCodeableConcept: struct (nullable = true)
#  |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- valueQuantity: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |-- unit: string (nullable = true)
#  |    |    |    |    |-- value: double (nullable = true)
#  |    |    |    |-- verificationStatus: struct (nullable = true)
#  |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |-- resourceType: string (nullable = true)
#  |-- type: string (nullable = true)
# [Row(entry=[Row(fullUrl='urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1', request=Row(method='POST', url='Patient'), resource=Row(abatementDateTime=None, address=[Row(city='Sherbrooke', country='CA', extension=[Row(extension=[Row(url='latitude', valueDecimal=45.39148379000888), Row(url='longitude', valueDecimal=-71.89263429922619)], url='http://hl7.org/fhir/StructureDefinition/geolocation')], line=['964 Wiza Dale'], postalCode='J1N', state='Quebec')], authoredOn=None, billablePeriod=None, birthDate='1975-10-22', careTeam=None, category=None, claim=None, class=None, clinicalStatus=None, code=None, communication=[Row(language=Row(coding=[Row(code='en-US', display='English', system='urn:ietf:bcp:47')], text='English'))], component=None, contained=None, created=None, deceasedDateTime='1984-09-18T13:01:28-04:00', diagnosis=None, effectiveDateTime=None, encounter=None, extension=[Row(url='http://hl7.org/fhir/StructureDefinition/patient-mothersMaidenName', valueAddress=None, valueDecimal=None, valueString='Yong583 Daniel959'), Row(url='http://hl7.org/fhir/StructureDefinition/patient-birthPlace', valueAddress=Row(city='Montréal', country='CA', state='Quebec'), valueDecimal=None, valueString=None), Row(url='http://synthetichealth.github.io/synthea/disability-adjusted-life-years', valueAddress=None, valueDecimal=0.6352185052180279, valueString=None), Row(url='http://synthetichealth.github.io/synthea/quality-adjusted-life-years', valueAddress=None, valueDecimal=7.3647814947819725, valueString=None)], gender='male', hospitalization=None, id='9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1', identifier=[Row(system='https://github.com/synthetichealth/synthea', type=None, value='9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1'), Row(system='http://hospital.smarthealthit.org', type=Row(coding=[Row(code='MR', display='Medical Record Number', system='http://terminology.hl7.org/CodeSystem/v2-0203')], text='Medical Record Number'), value='9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1'), Row(system='http://hl7.org/fhir/sid/us-ssn', type=Row(coding=[Row(code='SS', display='Social Security Number', system='http://terminology.hl7.org/CodeSystem/v2-0203')], text='Social Security Number'), value='999-91-6185')], insurance=None, insurer=None, intent=None, issued=None, item=None, maritalStatus=Row(coding=[Row(code='S', display='Never Married', system='http://terminology.hl7.org/CodeSystem/v3-MaritalStatus')], text='Never Married'), medicationCodeableConcept=None, multipleBirthBoolean=False, name=[Row(family='Gusikowski974', given=['Abdul218'], use='official')], occurrenceDateTime=None, onsetDateTime=None, outcome=None, participant=None, patient=None, payment=None, performedPeriod=None, period=None, prescription=None, primarySource=None, priority=None, procedure=None, provider=None, reasonCode=None, reasonReference=None, recordedDate=None, referral=None, requester=None, resourceType='Patient', result=None, serviceProvider=None, status=None, subject=None, supportingInfo=None, telecom=[Row(system='phone', use='home', value='555-742-3045')], text=Row(div='<div xmlns="http://www.w3.org/1999/xhtml">Generated by <a href="https://github.com/synthetichealth/synthea">Synthea</a>.Version identifier: master-branch-latest-1-g079b1eb0\n .   Person seed: 2086033354855757824  Population seed: 1620853518288</div>', status='generated'), total=None, type=None, use=None, vaccineCode=None, valueCodeableConcept=None, valueQuantity=None, verificationStatus=None)), Row(fullUrl='urn:uuid:bfc04826-0c53-f1b6-cdb2-6a49dba3402e', request=Row(method='POST', url='Encounter'), resource=Row(abatementDateTime=None, address=None, authoredOn=None, billablePeriod=None, birthDate=None, careTeam=None, category=None, claim=None, class=Row(code='AMB', system='http://terminology.hl7.org/CodeSystem/v3-ActCode'), clinicalStatus=None, code=None, communication=None, component=None, contained=None, created=None, deceasedDateTime=None, diagnosis=None, effectiveDateTime=None, encounter=None, extension=None, gender=None, hospitalizati ...

# %%
# Step 2: Parse the JSON and extract relevant fields
# Exploding entries from the Bundle
entries_df = df_raw.select(explode(col("entry")).alias("entry"))
entries_df.head()
# Out:
# Row(entry=Row(fullUrl='urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1', request=Row(method='POST', url='Patient'), resource=Row(abatementDateTime=None, address=[Row(city='Sherbrooke', country='CA', extension=[Row(extension=[Row(url='latitude', valueDecimal=45.39148379000888), Row(url='longitude', valueDecimal=-71.89263429922619)], url='http://hl7.org/fhir/StructureDefinition/geolocation')], line=['964 Wiza Dale'], postalCode='J1N', state='Quebec')], authoredOn=None, billablePeriod=None, birthDate='1975-10-22', careTeam=None, category=None, claim=None, class=None, clinicalStatus=None, code=None, communication=[Row(language=Row(coding=[Row(code='en-US', display='English', system='urn:ietf:bcp:47')], text='English'))], component=None, contained=None, created=None, deceasedDateTime='1984-09-18T13:01:28-04:00', diagnosis=None, effectiveDateTime=None, encounter=None, extension=[Row(url='http://hl7.org/fhir/StructureDefinition/patient-mothersMaidenName', valueAddress=None, valueDecimal=None, valueString='Yong583 Daniel959'), Row(url='http://hl7.org/fhir/StructureDefinition/patient-birthPlace', valueAddress=Row(city='Montréal', country='CA', state='Quebec'), valueDecimal=None, valueString=None), Row(url='http://synthetichealth.github.io/synthea/disability-adjusted-life-years', valueAddress=None, valueDecimal=0.6352185052180279, valueString=None), Row(url='http://synthetichealth.github.io/synthea/quality-adjusted-life-years', valueAddress=None, valueDecimal=7.3647814947819725, valueString=None)], gender='male', hospitalization=None, id='9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1', identifier=[Row(system='https://github.com/synthetichealth/synthea', type=None, value='9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1'), Row(system='http://hospital.smarthealthit.org', type=Row(coding=[Row(code='MR', display='Medical Record Number', system='http://terminology.hl7.org/CodeSystem/v2-0203')], text='Medical Record Number'), value='9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1'), Row(system='http://hl7.org/fhir/sid/us-ssn', type=Row(coding=[Row(code='SS', display='Social Security Number', system='http://terminology.hl7.org/CodeSystem/v2-0203')], text='Social Security Number'), value='999-91-6185')], insurance=None, insurer=None, intent=None, issued=None, item=None, maritalStatus=Row(coding=[Row(code='S', display='Never Married', system='http://terminology.hl7.org/CodeSystem/v3-MaritalStatus')], text='Never Married'), medicationCodeableConcept=None, multipleBirthBoolean=False, name=[Row(family='Gusikowski974', given=['Abdul218'], use='official')], occurrenceDateTime=None, onsetDateTime=None, outcome=None, participant=None, patient=None, payment=None, performedPeriod=None, period=None, prescription=None, primarySource=None, priority=None, procedure=None, provider=None, reasonCode=None, reasonReference=None, recordedDate=None, referral=None, requester=None, resourceType='Patient', result=None, serviceProvider=None, status=None, subject=None, supportingInfo=None, telecom=[Row(system='phone', use='home', value='555-742-3045')], text=Row(div='<div xmlns="http://www.w3.org/1999/xhtml">Generated by <a href="https://github.com/synthetichealth/synthea">Synthea</a>.Version identifier: master-branch-latest-1-g079b1eb0\n .   Person seed: 2086033354855757824  Population seed: 1620853518288</div>', status='generated'), total=None, type=None, use=None, vaccineCode=None, valueCodeableConcept=None, valueQuantity=None, verificationStatus=None)))

# %%
# Extract resource types
resource_types_df = entries_df.select(
    col("entry.resource.resourceType").alias("resourceType")
).distinct()

resource_types_df.orderBy('resourceType').show(truncate=False)
# Out:
# +--------------------+
# |resourceType        |
# +--------------------+
# |Claim               |
# |Condition           |
# |DiagnosticReport    |
# |Encounter           |
# |ExplanationOfBenefit|
# |Immunization        |
# |MedicationRequest   |
# |Observation         |
# |Patient             |
# |Procedure           |
# +--------------------+

# %%
# Extract patient information from resource
patients_df = entries_df.filter(col("entry.resource.resourceType") == "Patient").select(
    col("entry.resource.id").alias("patient_id"),
    col("entry.resource.gender").alias("gender"),
    col("entry.resource.birthDate").alias("birth_date"),
    col("entry.resource.name").alias("name"),
    col("entry.resource.address").alias("address")
)

# Show patient data
patients_df.show(truncate=False)
# Out:
# +------------------------------------+------+----------+---------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |patient_id                          |gender|birth_date|name                                   |address                                                                                                                                                                    |
# +------------------------------------+------+----------+---------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|male  |1975-10-22|[{Gusikowski974, [Abdul218], official}]|[{Sherbrooke, CA, [{[{latitude, 45.39148379000888}, {longitude, -71.89263429922619}], http://hl7.org/fhir/StructureDefinition/geolocation}], [964 Wiza Dale], J1N, Quebec}]|
# +------------------------------------+------+----------+---------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
# Flatten patient names
names_df = patients_df.select(
    col("patient_id"),
    explode(col("name")).alias("name_details")
).select(
    col("patient_id"),
    col("name_details.family").alias("last_name"),
    col("name_details.given").alias("first_name")
)

# Flatten patient addresses
addresses_df = patients_df.select(
    col("patient_id"),
    explode(col("address")).alias("address_details")
).select(
    col("patient_id"),
    col("address_details.city").alias("city"),
    col("address_details.state").alias("state"),
    col("address_details.country").alias("country")
)

# Show flattened data
names_df.show(truncate=False)
addresses_df.show(truncate=False)
# Out:
# +------------------------------------+-------------+----------+
# |patient_id                          |last_name    |first_name|
# +------------------------------------+-------------+----------+
# |9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|Gusikowski974|[Abdul218]|
# +------------------------------------+-------------+----------+
#
# +------------------------------------+----------+------+-------+
# |patient_id                          |city      |state |country|
# +------------------------------------+----------+------+-------+
# |9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|Sherbrooke|Quebec|CA     |
# +------------------------------------+----------+------+-------+

# %%
# Extract encounter data
encounters_df = entries_df.filter(col("entry.resource.resourceType") == "Encounter").select(
    col("entry.resource.id").alias("encounter_id"),
    col("entry.resource.subject.reference").alias("patient_reference"),
    col("entry.resource.period.start").alias("start_time"),
    col("entry.resource.period.end").alias("end_time"),
    col("entry.resource.serviceProvider.display").alias("service_provider")
)

# Show encounter data
encounters_df.show(truncate=False)
# Out:
# +------------------------------------+---------------------------------------------+-------------------------+-------------------------+---------------------------+
# |encounter_id                        |patient_reference                            |start_time               |end_time                 |service_provider           |
# +------------------------------------+---------------------------------------------+-------------------------+-------------------------+---------------------------+
# |bfc04826-0c53-f1b6-cdb2-6a49dba3402e|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|1975-10-22T13:01:28-04:00|1975-10-22T13:16:28-04:00|CLSC J-OLIVIER-CAMIRAND    |
# |808b2737-7039-9fcf-d26a-c199c8db91a0|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|1975-11-26T12:01:28-05:00|1975-11-26T12:16:28-05:00|CLSC J-OLIVIER-CAMIRAND    |
# |7645e9a2-b178-d528-9729-be9fd44093e4|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|1976-01-28T12:01:28-05:00|1976-01-28T12:16:28-05:00|CLSC J-OLIVIER-CAMIRAND    |
# |5095c5d9-cb41-8170-4004-ead0ca55059b|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|1976-03-31T12:01:28-05:00|1976-03-31T12:16:28-05:00|CLSC J-OLIVIER-CAMIRAND    |
# |b0fff8cf-34ab-9025-82d5-f6fc4bdfdddc|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|1976-06-30T13:01:28-04:00|1976-06-30T13:16:28-04:00|CLSC J-OLIVIER-CAMIRAND    |
# |07a09621-f89c-17a2-4db1-574f32c74256|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|1976-09-29T13:01:28-04:00|1976-09-29T13:16:28-04:00|CLSC J-OLIVIER-CAMIRAND    |
# |c9ba3ff7-fad1-df49-ca05-896a434c59bb|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|1976-12-29T12:01:28-05:00|1976-12-29T12:16:28-05:00|CLSC J-OLIVIER-CAMIRAND    |
# |d5f51aeb-1558-35c8-227d-2e82d0d74e2e|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|1977-03-30T12:01:28-05:00|1977-03-30T12:16:28-05:00|CLSC J-OLIVIER-CAMIRAND    |
# |1e163045-e37f-c8eb-9a9b-9d3e86b0dbf9|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|1977-06-15T01:01:28-04:00|1977-06-15T01:16:28-04:00|HФPITAL ET CHSLD D'YOUVILLE|
# |dcb04768-c378-18a4-3990-a0d87986b83c|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|1977-06-22T13:01:28-04:00|1977-06-22T13:16:28-04:00|HФPITAL ET CHSLD D'YOUVILLE|
# |6ca3894e-cda0-2980-be5c-48c295ec4f11|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|1977-06-29T13:01:28-04:00|1977-06-29T13:16:28-04:00|HФPITAL ET CHSLD D'YOUVILLE|
# |cc39d5d1-3143-03a2-29a2-27689acd6eb4|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|1977-09-28T13:01:28-04:00|1977-09-28T13:16:28-04:00|CLSC J-OLIVIER-CAMIRAND    |
# |aa91b6c4-62c8-26be-6dfd-53e8393f1297|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|1978-03-29T12:01:28-05:00|1978-03-29T12:16:28-05:00|CLSC J-OLIVIER-CAMIRAND    |
# |68271ae7-f0dd-3240-1d0f-c2dbab073c6f|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|1978-09-27T13:01:28-04:00|1978-09-27T13:16:28-04:00|CLSC J-OLIVIER-CAMIRAND    |
# |59887ae2-cc46-9a0d-3a70-a961addf2dff|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|1979-03-28T12:01:28-05:00|1979-03-28T12:16:28-05:00|CLSC J-OLIVIER-CAMIRAND    |
# |27f8e3ce-76b7-60cc-29aa-c6f6984b2ab8|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|1979-09-26T13:01:28-04:00|1979-09-26T13:16:28-04:00|CLSC J-OLIVIER-CAMIRAND    |
# |b355464c-dafc-5c17-f72d-03c3fdedbe35|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|1979-10-11T08:01:28-04:00|1979-10-11T08:16:28-04:00|HФPITAL ET CHSLD D'YOUVILLE|
# |fece2c29-2b42-3bee-1149-0b764feb883c|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|1980-05-16T13:01:28-04:00|1980-05-16T15:25:49-04:00|HФPITAL ET CHSLD D'YOUVILLE|
# |27c58e95-3227-bde5-2e05-84bd282326b8|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|1980-10-01T13:01:28-04:00|1980-10-01T13:16:28-04:00|CLSC J-OLIVIER-CAMIRAND    |
# |14f606cf-f3ae-94d6-2c42-d2f436dd4a62|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|1981-10-07T13:01:28-04:00|1981-10-07T13:16:28-04:00|CLSC J-OLIVIER-CAMIRAND    |
# +------------------------------------+---------------------------------------------+-------------------------+-------------------------+---------------------------+
# only showing top 20 rows

# %%
# Extract observation data
observations_df = entries_df.filter(col("entry.resource.resourceType") == "Observation").select(
    col("entry.resource.id").alias("observation_id"),
    col("entry.resource.subject.reference").alias("patient_reference"),
    col("entry.resource.code.text").alias("observation_text"),
    col("entry.resource.valueQuantity.value").alias("value"),
    col("entry.resource.valueQuantity.unit").alias("unit")
)

# Show observation data
observations_df.show(truncate=False)
# Out:
# +------------------------------------+---------------------------------------------+------------------------------------------------------------------------+------+-------+
# |observation_id                      |patient_reference                            |observation_text                                                        |value |unit   |
# +------------------------------------+---------------------------------------------+------------------------------------------------------------------------+------+-------+
# |6686979d-3883-1892-715a-4c1a400db8c1|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|Body Height                                                             |52.6  |cm     |
# |62d6c91c-a5a1-175b-8ffe-a7051e730e89|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|Pain severity - 0-10 verbal numeric rating [Score] - Reported           |3.0   |{score}|
# |c77ae5fa-b25e-b423-df0a-438ce24ac549|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|Body Weight                                                             |3.5   |kg     |
# |938fc444-697c-1bf6-a154-cb684d7b4f16|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|Weight-for-length Per age and sex                                       |2.3583|%      |
# |84de9884-d260-721d-2d11-e171fb9c773d|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|Head Occipital-frontal circumference                                    |35.72 |cm     |
# |e95d50e5-c504-8fa1-1485-44e31a3b1762|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|Blood Pressure                                                          |NULL  |NULL   |
# |1df10d7d-604b-b70e-ebf9-73c3a3c07aec|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|Heart rate                                                              |98.0  |/min   |
# |de6f49df-d24d-4078-cd59-809db7e214a0|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|Respiratory rate                                                        |15.0  |/min   |
# |f58f8bfc-68be-81c2-92a6-0f7563a46a8c|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|Leukocytes [#/volume] in Blood by Automated count                       |7.4825|10*3/uL|
# |3448ac24-7cdc-771d-0788-adf386465c25|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|Erythrocytes [#/volume] in Blood by Automated count                     |5.1263|10*6/uL|
# |2c320a6c-2628-efcf-36c7-fae91e1826b3|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|Hemoglobin [Mass/volume] in Blood                                       |15.295|g/dL   |
# |d9324538-1a47-4335-5d92-50f26a93cbed|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|Hematocrit [Volume Fraction] of Blood by Automated count                |41.599|%      |
# |e94a450f-6a80-d20a-cbbb-e8781e42bedf|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|MCV [Entitic volume] by Automated count                                 |93.98 |fL     |
# |6ee4b1b4-1939-d7e9-1868-a4dc9d56fb13|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|MCH [Entitic mass] by Automated count                                   |27.183|pg     |
# |9fff2476-bf23-5110-1569-00f0ab9be9f0|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|MCHC [Mass/volume] by Automated count                                   |34.553|g/dL   |
# |8403abc7-a17e-f866-0414-cea947c5ba5c|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|Erythrocyte distribution width [Entitic volume] by Automated count      |42.518|fL     |
# |a07e740b-ec96-a1bf-e3e5-be11f96c0ea9|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|Platelets [#/volume] in Blood by Automated count                        |254.24|10*3/uL|
# |6b44a9b2-ffd8-745d-a0be-df81e46724ad|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|Platelet distribution width [Entitic volume] in Blood by Automated count|419.32|fL     |
# |745ee88a-601d-c9b9-3bed-95114614dc32|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|Platelet mean volume [Entitic volume] in Blood by Automated count       |11.606|fL     |
# |5c5acc4c-80ba-b483-4ac3-a746f97d3f91|urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1|Tobacco smoking status NHIS                                             |NULL  |NULL   |
# +------------------------------------+---------------------------------------------+------------------------------------------------------------------------+------+-------+
# only showing top 20 rows

# %%
# List of resource types to extract
resource_types = [
    "CarePlan", "CareTeam", "Claim", "Condition", "DiagnosticReport",
    "Encounter", "ExplanationOfBenefit", "Immunization", "MedicationRequest",
    "Observation", "Patient", "Procedure"
]

# Dictionary to hold DataFrames for each resource type
resource_dfs = {}

# Loop through each resource type and filter
for resource_type in resource_types:
    resource_dfs[resource_type] = entries_df.filter(
        col("entry.resource.resourceType") == resource_type
    ).select(
        col("entry.resource.*")  # Select all fields within `resource`
    )


# Define the output folder path for storing results
output_folder = "checkpoint_1"

if not os.path.exists(output_folder):
        os.makedirs(output_folder)

# Save each resource DataFrame as Parquet in the specified folder
for resource_type, resource_df in resource_dfs.items():
    resource_df.write.parquet(f"{output_folder}/{resource_type.lower()}", mode="overwrite")

# %% [markdown]
# # Breaking down each parquet

# %%
base_path = 'checkpoint_1'

output_folder = "checkpoint_2"
if not os.path.exists(output_folder):
        os.makedirs(output_folder)
        
# Loop through each resource type
for resource_type in resource_types:
    folder_path = os.path.join(base_path, resource_type.lower())
    
    # Read the Parquet file
    df = spark.read.parquet(folder_path)
    
    print(f"Resource: {resource_type}")
    
    # Print the list of columns
    all_columns = df.columns
    print(f"All Columns: {all_columns}")
    
    # Identify non-null columns
    non_null_columns = [column for column in all_columns if df.select(col(column)).distinct().count() > 1]
    print(f"Non-Null Columns: {non_null_columns}")
    
    # Create a DataFrame with only non-null columns
    df_non_null = df.select(*non_null_columns)
    
    print(f"DataFrame with Non-Null Columns for {resource_type}:")
    df_non_null.show(truncate=False)
    
    # df_non_null.write.parquet(f"{output_folder}/{resource_type.lower()}_non_null", mode="overwrite")
# Out:
# Resource: CarePlan
# All Columns: ['abatementDateTime', 'address', 'authoredOn', 'billablePeriod', 'birthDate', 'careTeam', 'category', 'claim', 'class', 'clinicalStatus', 'code', 'communication', 'component', 'contained', 'created', 'deceasedDateTime', 'diagnosis', 'effectiveDateTime', 'encounter', 'extension', 'gender', 'hospitalization', 'id', 'identifier', 'insurance', 'insurer', 'intent', 'issued', 'item', 'maritalStatus', 'medicationCodeableConcept', 'multipleBirthBoolean', 'name', 'occurrenceDateTime', 'onsetDateTime', 'outcome', 'participant', 'patient', 'payment', 'performedPeriod', 'period', 'prescription', 'primarySource', 'priority', 'procedure', 'provider', 'reasonCode', 'reasonReference', 'recordedDate', 'referral', 'requester', 'resourceType', 'result', 'serviceProvider', 'status', 'subject', 'supportingInfo', 'telecom', 'text', 'total', 'type', 'use', 'vaccineCode', 'valueCodeableConcept', 'valueQuantity', 'verificationStatus']
# Non-Null Columns: []
# DataFrame with Non-Null Columns for CarePlan:
# ++
# ||
# ++
# ++
#
# Resource: CareTeam
# All Columns: ['abatementDateTime', 'address', 'authoredOn', 'billablePeriod', 'birthDate', 'careTeam', 'category', 'claim', 'class', 'clinicalStatus', 'code', 'communication', 'component', 'contained', 'created', 'deceasedDateTime', 'diagnosis', 'effectiveDateTime', 'encounter', 'extension', 'gender', 'hospitalization', 'id', 'identifier', 'insurance', 'insurer', 'intent', 'issued', 'item', 'maritalStatus', 'medicationCodeableConcept', 'multipleBirthBoolean', 'name', 'occurrenceDateTime', 'onsetDateTime', 'outcome', 'participant', 'patient', 'payment', 'performedPeriod', 'period', 'prescription', 'primarySource', 'priority', 'procedure', 'provider', 'reasonCode', 'reasonReference', 'recordedDate', 'referral', 'requester', 'resourceType', 'result', 'serviceProvider', 'status', 'subject', 'supportingInfo', 'telecom', 'text', 'total', 'type', 'use', 'vaccineCode', 'valueCodeableConcept', 'valueQuantity', 'verificationStatus']
# Non-Null Columns: []
# DataFrame with Non-Null Columns for CareTeam:
# ++
# ||
# ++
# ++
#
# Resource: Claim
# All Columns: ['abatementDateTime', 'address', 'authoredOn', 'billablePeriod', 'birthDate', 'careTeam', 'category', 'claim', 'class', 'clinicalStatus', 'code', 'communication', 'component', 'contained', 'created', 'deceasedDateTime', 'diagnosis', 'effectiveDateTime', 'encounter', 'extension', 'gender', 'hospitalization', 'id', 'identifier', 'insurance', 'insurer', 'intent', 'issued', 'item', 'maritalStatus', 'medicationCodeableConcept', 'multipleBirthBoolean', 'name', 'occurrenceDateTime', 'onsetDateTime', 'outcome', 'participant', 'patient', 'payment', 'performedPeriod', 'period', 'prescription', 'primarySource', 'priority', 'procedure', 'provider', 'reasonCode', 'reasonReference', 'recordedDate', 'referral', 'requester', 'resourceType', 'result', 'serviceProvider', 'status', 'subject', 'supportingInfo', 'telecom', 'text', 'total', 'type', 'use', 'vaccineCode', 'valueCodeableConcept', 'valueQuantity', 'verificationStatus']
# Non-Null Columns: ['billablePeriod', 'created', 'diagnosis', 'id', 'item', 'patient', 'prescription', 'procedure', 'provider', 'supportingInfo', 'total', 'type']
# DataFrame with Non-Null Columns for Claim:
# +------------------------------------------------------+-------------------------+------------------------------------------------------------------------------------------------------------------------+------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------+-----------------------------------------------+------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------+-------------------------------------------------------------------------------------------------+
# |billablePeriod                                        |created                  |diagnosis                                                                                                               |id                                  |item                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |patient                                                                |prescription                                   |procedure                                             |provider                                                                                                                              |supportingInfo                                                                                                                                                                                                                                                      |total                             |type                                                                                             |
# +------------------------------------------------------+-------------------------+------------------------------------------------------------------------------------------------------------------------+------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------+-----------------------------------------------+------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------+-------------------------------------------------------------------------------------------------+
# |{1975-10-22T13:16:28-04:00, 1975-10-22T13:01:28-04:00}|1975-10-22T13:16:28-04:00|NULL                                                                                                                    |2e78f8d0-de28-d4f4-48cc-fdbdf9751b4c|[{NULL, NULL, NULL, [{urn:uuid:bfc04826-0c53-f1b6-cdb2-6a49dba3402e}], NULL, NULL, NULL, NULL, {[{410620009, Well child visit (procedure), http://snomed.info/sct}], Well child visit (procedure)}, 1, NULL}, {NULL, NULL, NULL, NULL, NULL, NULL, {USD, 522.56}, [1], {[{430193006, Medication Reconciliation (procedure), http://snomed.info/sct}], Medication Reconciliation (procedure)}, 2, NULL}]                                                                                                                                                                                                                                                                                                                                                     |{Abdul218 Gusikowski974, urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1}|NULL                                           |[{{urn:uuid:19cc767f-f150-73e8-c771-711584a47298}, 1}]|{CLSC J-OLIVIER-CAMIRAND, Organization?identifier=https://github.com/synthetichealth/synthea|8e9ecbd4-ae45-3256-93e7-95085fac346d}    |NULL                                                                                                                                                                                                                                                                |{"value":125.0,"currency":"USD"}  |{"coding":[{"system":"http://terminology.hl7.org/CodeSystem/claim-type","code":"institutional"}]}|
# |{1975-11-26T12:16:28-05:00, 1975-11-26T12:01:28-05:00}|1975-11-26T12:16:28-05:00|NULL                                                                                                                    |52d06c7b-1e24-8c6d-9814-5eecfd4dc761|[{NULL, NULL, NULL, [{urn:uuid:808b2737-7039-9fcf-d26a-c199c8db91a0}], NULL, NULL, NULL, NULL, {[{410620009, Well child visit (procedure), http://snomed.info/sct}], Well child visit (procedure)}, 1, NULL}, {NULL, NULL, NULL, NULL, NULL, NULL, {USD, 585.64}, [1], {[{430193006, Medication Reconciliation (procedure), http://snomed.info/sct}], Medication Reconciliation (procedure)}, 2, NULL}]                                                                                                                                                                                                                                                                                                                                                     |{Abdul218 Gusikowski974, urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1}|NULL                                           |[{{urn:uuid:c8d99769-583c-3d68-f7d0-c0673ac17d8d}, 1}]|{CLSC J-OLIVIER-CAMIRAND, Organization?identifier=https://github.com/synthetichealth/synthea|8e9ecbd4-ae45-3256-93e7-95085fac346d}    |NULL                                                                                                                                                                                                                                                                |{"value":125.0,"currency":"USD"}  |{"coding":[{"system":"http://terminology.hl7.org/CodeSystem/claim-type","code":"institutional"}]}|
# |{1976-01-28T12:16:28-05:00, 1976-01-28T12:01:28-05:00}|1976-01-28T12:16:28-05:00|NULL                                                                                                                    |47e3d965-0964-5348-2e65-3641ffffecf6|[{NULL, NULL, NULL, [{urn:uuid:7645e9a2-b178-d528-9729-be9fd44093e4}], NULL, NULL, NULL, NULL, {[{410620009, Well child visit (procedure), http://snomed.info/sct}], Well child visit (procedure)}, 1, NULL}, {NULL, NULL, NULL, NULL, [1], NULL, {USD, 136.0}, NULL, {[{10, IPV, http://hl7.org/fhir/sid/cvx}], IPV}, 2, NULL}]                                                                                                                                                                                                                                                                                                                                                                                                                            |{Abdul218 Gusikowski974, urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1}|NULL                                           |NULL                                                  |{CLSC J-OLIVIER-CAMIRAND, Organization?identifier=https://github.com/synthetichealth/synthea|8e9ecbd4-ae45-3256-93e7-95085fac346d}    |[{{[{info, http://terminology.hl7.org/CodeSystem/claiminformationcategory}]}, 1, {urn:uuid:32237349-8778-676b-c185-2f0ceca62acd}}]                                                                                                                                  |{"value":125.0,"currency":"USD"}  |{"coding":[{"system":"http://terminology.hl7.org/CodeSystem/claim-type","code":"institutional"}]}|
# |{1976-03-31T12:16:28-05:00, 1976-03-31T12:01:28-05:00}|1976-03-31T12:16:28-05:00|NULL                                                                                                                    |607e5371-87bf-7082-06ad-3b2666d448e1|[{NULL, NULL, NULL, [{urn:uuid:5095c5d9-cb41-8170-4004-ead0ca55059b}], NULL, NULL, NULL, NULL, {[{410620009, Well child visit (procedure), http://snomed.info/sct}], Well child visit (procedure)}, 1, NULL}, {NULL, NULL, NULL, NULL, [1], NULL, {USD, 136.0}, NULL, {[{10, IPV, http://hl7.org/fhir/sid/cvx}], IPV}, 2, NULL}, {NULL, NULL, NULL, NULL, NULL, NULL, {USD, 716.78}, [1], {[{430193006, Medication Reconciliation (procedure), http://snomed.info/sct}], Medication Reconciliation (procedure)}, 3, NULL}]                                                                                                                                                                                                                                  |{Abdul218 Gusikowski974, urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1}|NULL                                           |[{{urn:uuid:f239e469-387d-8b23-ccc4-eff873a1a321}, 1}]|{CLSC J-OLIVIER-CAMIRAND, Organization?identifier=https://github.com/synthetichealth/synthea|8e9ecbd4-ae45-3256-93e7-95085fac346d}    |[{{[{info, http://terminology.hl7.org/CodeSystem/claiminformationcategory}]}, 1, {urn:uuid:3ee325df-fe3f-5069-0321-a66cbb7eeaf8}}]                                                                                                                                  |{"value":125.0,"currency":"USD"}  |{"coding":[{"system":"http://terminology.hl7.org/CodeSystem/claim-type","code":"institutional"}]}|
# |{1976-06-30T13:16:28-04:00, 1976-06-30T13:01:28-04:00}|1976-06-30T13:16:28-04:00|NULL                                                                                                                    |b1aad39e-4a3a-ef71-0b5c-9111448050ec|[{NULL, NULL, NULL, [{urn:uuid:b0fff8cf-34ab-9025-82d5-f6fc4bdfdddc}], NULL, NULL, NULL, NULL, {[{410620009, Well child visit (procedure), http://snomed.info/sct}], Well child visit (procedure)}, 1, NULL}, {NULL, NULL, NULL, NULL, [1], NULL, {USD, 136.0}, NULL, {[{10, IPV, http://hl7.org/fhir/sid/cvx}], IPV}, 2, NULL}, {NULL, NULL, NULL, NULL, [2], NULL, {USD, 136.0}, NULL, {[{140, Influenza, seasonal, injectable, preservative free, http://hl7.org/fhir/sid/cvx}], Influenza, seasonal, injectable, preservative free}, 3, NULL}, {NULL, NULL, NULL, NULL, NULL, NULL, {USD, 323.92}, [1], {[{430193006, Medication Reconciliation (procedure), http://snomed.info/sct}], Medication Reconciliation (procedure)}, 4, NULL}]                |{Abdul218 Gusikowski974, urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1}|NULL                                           |[{{urn:uuid:3d40f44f-45d5-3d8c-5fdb-a1b029d6cd8a}, 1}]|{CLSC J-OLIVIER-CAMIRAND, Organization?identifier=https://github.com/synthetichealth/synthea|8e9ecbd4-ae45-3256-93e7-95085fac346d}    |[{{[{info, http://terminology.hl7.org/CodeSystem/claiminformationcategory}]}, 1, {urn:uuid:be0355a4-ca96-70ed-0517-32c951161a28}}, {{[{info, http://terminology.hl7.org/CodeSystem/claiminformationcategory}]}, 2, {urn:uuid:00d927e4-4ebf-9ad6-9282-250296b06bc1}}]|{"value":125.0,"currency":"USD"}  |{"coding":[{"system":"http://terminology.hl7.org/CodeSystem/claim-type","code":"institutional"}]}|
# |{1976-09-29T13:16:28-04:00, 1976-09-29T13:01:28-04:00}|1976-09-29T13:16:28-04:00|NULL                                                                                                                    |0fd831e3-71db-0248-4a2c-60c1e3e22ded|[{NULL, NULL, NULL, [{urn:uuid:07a09621-f89c-17a2-4db1-574f32c74256}], NULL, NULL, NULL, NULL, {[{410620009, Well child visit (procedure), http://snomed.info/sct}], Well child visit (procedure)}, 1, NULL}, {NULL, NULL, NULL, NULL, NULL, NULL, {USD, 736.81}, [1], {[{430193006, Medication Reconciliation (procedure), http://snomed.info/sct}], Medication Reconciliation (procedure)}, 2, NULL}]                                                                                                                                                                                                                                                                                                                                                     |{Abdul218 Gusikowski974, urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1}|NULL                                           |[{{urn:uuid:c03f340b-0062-327f-361f-896275ee3b04}, 1}]|{CLSC J-OLIVIER-CAMIRAND, Organization?identifier=https://github.com/synthetichealth/synthea|8e9ecbd4-ae45-3256-93e7-95085fac346d}    |NULL                                                                                                                                                                                                                                                                |{"value":125.0,"currency":"USD"}  |{"coding":[{"system":"http://terminology.hl7.org/CodeSystem/claim-type","code":"institutional"}]}|
# |{1976-12-29T12:16:28-05:00, 1976-12-29T12:01:28-05:00}|1976-12-29T12:16:28-05:00|NULL                                                                                                                    |bbf9ab97-a2a8-c427-bb7a-10ad3a9afb59|[{NULL, NULL, NULL, [{urn:uuid:c9ba3ff7-fad1-df49-ca05-896a434c59bb}], NULL, NULL, NULL, NULL, {[{410620009, Well child visit (procedure), http://snomed.info/sct}], Well child visit (procedure)}, 1, NULL}, {NULL, NULL, NULL, NULL, [1], NULL, {USD, 136.0}, NULL, {[{03, MMR, http://hl7.org/fhir/sid/cvx}], MMR}, 2, NULL}]                                                                                                                                                                                                                                                                                                                                                                                                                            |{Abdul218 Gusikowski974, urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1}|NULL                                           |NULL                                                  |{CLSC J-OLIVIER-CAMIRAND, Organization?identifier=https://github.com/synthetichealth/synthea|8e9ecbd4-ae45-3256-93e7-95085fac346d}    |[{{[{info, http://terminology.hl7.org/CodeSystem/claiminformationcategory}]}, 1, {urn:uuid:61c4e169-8f8d-8d52-517a-f5b09e9a1ecc}}]                                                                                                                                  |{"value":125.0,"currency":"USD"}  |{"coding":[{"system":"http://terminology.hl7.org/CodeSystem/claim-type","code":"institutional"}]}|
# |{1977-03-30T12:16:28-05:00, 1977-03-30T12:01:28-05:00}|1977-03-30T12:16:28-05:00|NULL                                                                                                                    |d96039d1-d6e1-37cb-9d5c-1b4ac6c3bb87|[{NULL, NULL, NULL, [{urn:uuid:d5f51aeb-1558-35c8-227d-2e82d0d74e2e}], NULL, NULL, NULL, NULL, {[{410620009, Well child visit (procedure), http://snomed.info/sct}], Well child visit (procedure)}, 1, NULL}, {NULL, NULL, NULL, NULL, [1], NULL, {USD, 136.0}, NULL, {[{49, Hib (PRP-OMP), http://hl7.org/fhir/sid/cvx}], Hib (PRP-OMP)}, 2, NULL}]                                                                                                                                                                                                                                                                                                                                                                                                        |{Abdul218 Gusikowski974, urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1}|NULL                                           |NULL                                                  |{CLSC J-OLIVIER-CAMIRAND, Organization?identifier=https://github.com/synthetichealth/synthea|8e9ecbd4-ae45-3256-93e7-95085fac346d}    |[{{[{info, http://terminology.hl7.org/CodeSystem/claiminformationcategory}]}, 1, {urn:uuid:f5fe754f-8c5f-0525-44e7-699a72bfb542}}]                                                                                                                                  |{"value":125.0,"currency":"USD"}  |{"coding":[{"system":"http://terminology.hl7.org/CodeSystem/claim-type","code":"institutional"}]}|
# |{1977-06-15T01:16:28-04:00, 1977-06-15T01:01:28-04:00}|1977-06-15T01:16:28-04:00|NULL                                                                                                                    |24a3511e-2db7-26a9-6edd-f07f2cdd8faa|[{NULL, NULL, NULL, [{urn:uuid:1e163045-e37f-c8eb-9a9b-9d3e86b0dbf9}], NULL, NULL, NULL, NULL, {[{185345009, Encounter for symptom, http://snomed.info/sct}], Encounter for symptom}, 1, NULL}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |{NULL, urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1}                  |{urn:uuid:590a3b67-0414-0886-cf21-99a2c0950287}|NULL                                                  |{HФPITAL ET CHSLD D'YOUVILLE, Organization?identifier=https://github.com/synthetichealth/synthea|6eb4830c-08de-3127-9453-f76bb44f3f0e}|NULL                                                                                                                                                                                                                                                                |{"value":20.47,"currency":"USD"}  |{"coding":[{"system":"http://terminology.hl7.org/CodeSystem/claim-type","code":"pharmacy"}]}     |
# |{1977-06-15T01:16:28-04:00, 1977-06-15T01:01:28-04:00}|1977-06-15T01:16:28-04:00|[{{urn:uuid:536764fb-309c-373f-dcdf-36eb0889f849}, 1, NULL}]                                                            |36c42c8e-39bf-9c4f-0a19-1b661d16462e|[{NULL, NULL, NULL, [{urn:uuid:1e163045-e37f-c8eb-9a9b-9d3e86b0dbf9}], NULL, NULL, NULL, NULL, {[{185345009, Encounter for symptom, http://snomed.info/sct}], Encounter for symptom}, 1, NULL}, {NULL, NULL, [1], NULL, NULL, NULL, NULL, NULL, {[{43878008, Streptococcal sore throat (disorder), http://snomed.info/sct}], Streptococcal sore throat (disorder)}, 2, NULL}]                                                                                                                                                                                                                                                                                                                                                                               |{Abdul218 Gusikowski974, urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1}|NULL                                           |NULL                                                  |{HФPITAL ET CHSLD D'YOUVILLE, Organization?identifier=https://github.com/synthetichealth/synthea|6eb4830c-08de-3127-9453-f76bb44f3f0e}|NULL                                                                                                                                                                                                                                                                |{"value":75.0,"currency":"USD"}   |{"coding":[{"system":"http://terminology.hl7.org/CodeSystem/claim-type","code":"institutional"}]}|
# |{1977-06-22T13:16:28-04:00, 1977-06-22T13:01:28-04:00}|1977-06-22T13:16:28-04:00|NULL                                                                                                                    |464e7c93-c314-b8bb-a096-98910ca4c59b|[{NULL, NULL, NULL, [{urn:uuid:dcb04768-c378-18a4-3990-a0d87986b83c}], NULL, NULL, NULL, NULL, {[{702927004, Urgent care clinic (procedure), http://snomed.info/sct}], Urgent care clinic (procedure)}, 1, NULL}, {NULL, NULL, NULL, NULL, [1], NULL, {USD, 136.0}, NULL, {[{49, Hib (PRP-OMP), http://hl7.org/fhir/sid/cvx}], Hib (PRP-OMP)}, 2, NULL}, {NULL, NULL, NULL, NULL, [2], NULL, {USD, 136.0}, NULL, {[{140, Influenza, seasonal, injectable, preservative free, http://hl7.org/fhir/sid/cvx}], Influenza, seasonal, injectable, preservative free}, 3, NULL}]                                                                                                                                                                                  |{Abdul218 Gusikowski974, urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1}|NULL                                           |NULL                                                  |{HФPITAL ET CHSLD D'YOUVILLE, Organization?identifier=https://github.com/synthetichealth/synthea|6eb4830c-08de-3127-9453-f76bb44f3f0e}|[{{[{info, http://terminology.hl7.org/CodeSystem/claiminformationcategory}]}, 1, {urn:uuid:f343197d-6241-a4e2-5a09-c0eeb588e92c}}, {{[{info, http://terminology.hl7.org/CodeSystem/claiminformationcategory}]}, 2, {urn:uuid:410ca484-d70c-af90-9391-c44eff426353}}]|{"value":125.0,"currency":"USD"}  |{"coding":[{"system":"http://terminology.hl7.org/CodeSystem/claim-type","code":"institutional"}]}|
# |{1977-06-29T13:16:28-04:00, 1977-06-29T13:01:28-04:00}|1977-06-29T13:16:28-04:00|NULL                                                                                                                    |1339c45b-83fe-8f3d-1641-9a39064632a9|[{NULL, NULL, NULL, [{urn:uuid:6ca3894e-cda0-2980-be5c-48c295ec4f11}], NULL, NULL, NULL, NULL, {[{185349003, Encounter for check up (procedure), http://snomed.info/sct}], Encounter for check up (procedure)}, 1, NULL}, {NULL, NULL, NULL, NULL, [1], NULL, {USD, 136.0}, NULL, {[{49, Hib (PRP-OMP), http://hl7.org/fhir/sid/cvx}], Hib (PRP-OMP)}, 2, NULL}]                                                                                                                                                                                                                                                                                                                                                                                            |{Abdul218 Gusikowski974, urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1}|NULL                                           |NULL                                                  |{HФPITAL ET CHSLD D'YOUVILLE, Organization?identifier=https://github.com/synthetichealth/synthea|6eb4830c-08de-3127-9453-f76bb44f3f0e}|[{{[{info, http://terminology.hl7.org/CodeSystem/claiminformationcategory}]}, 1, {urn:uuid:360e544d-6556-afa5-a8dc-574279cd6e46}}]                                                                                                                                  |{"value":75.0,"currency":"USD"}   |{"coding":[{"system":"http://terminology.hl7.org/CodeSystem/claim-type","code":"institutional"}]}|
# |{1977-09-28T13:16:28-04:00, 1977-09-28T13:01:28-04:00}|1977-09-28T13:16:28-04:00|NULL                                                                                                                    |cb9f6638-848e-155f-314e-c6df8dde6fc3|[{NULL, NULL, NULL, [{urn:uuid:cc39d5d1-3143-03a2-29a2-27689acd6eb4}], NULL, NULL, NULL, NULL, {[{410620009, Well child visit (procedure), http://snomed.info/sct}], Well child visit (procedure)}, 1, NULL}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |{Abdul218 Gusikowski974, urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1}|NULL                                           |NULL                                                  |{CLSC J-OLIVIER-CAMIRAND, Organization?identifier=https://github.com/synthetichealth/synthea|8e9ecbd4-ae45-3256-93e7-95085fac346d}    |NULL                                                                                                                                                                                                                                                                |{"value":125.0,"currency":"USD"}  |{"coding":[{"system":"http://terminology.hl7.org/CodeSystem/claim-type","code":"institutional"}]}|
# |{1978-03-29T12:16:28-05:00, 1978-03-29T12:01:28-05:00}|1978-03-29T12:16:28-05:00|NULL                                                                                                                    |c196f9eb-7cc5-84fa-7e26-ae213d4e54a5|[{NULL, NULL, NULL, [{urn:uuid:aa91b6c4-62c8-26be-6dfd-53e8393f1297}], NULL, NULL, NULL, NULL, {[{410620009, Well child visit (procedure), http://snomed.info/sct}], Well child visit (procedure)}, 1, NULL}, {NULL, NULL, NULL, NULL, NULL, NULL, {USD, 366.92}, [1], {[{430193006, Medication Reconciliation (procedure), http://snomed.info/sct}], Medication Reconciliation (procedure)}, 2, NULL}]                                                                                                                                                                                                                                                                                                                                                     |{Abdul218 Gusikowski974, urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1}|NULL                                           |[{{urn:uuid:1c2f7ae5-fe0c-2411-8a0e-0431e403d17d}, 1}]|{CLSC J-OLIVIER-CAMIRAND, Organization?identifier=https://github.com/synthetichealth/synthea|8e9ecbd4-ae45-3256-93e7-95085fac346d}    |NULL                                                                                                                                                                                                                                                                |{"value":125.0,"currency":"USD"}  |{"coding":[{"system":"http://terminology.hl7.org/CodeSystem/claim-type","code":"institutional"}]}|
# |{1978-09-27T13:16:28-04:00, 1978-09-27T13:01:28-04:00}|1978-09-27T13:16:28-04:00|NULL                                                                                                                    |69859bc2-7ef1-0ea8-a08b-3376f805fa60|[{NULL, NULL, NULL, [{urn:uuid:68271ae7-f0dd-3240-1d0f-c2dbab073c6f}], NULL, NULL, NULL, NULL, {[{410620009, Well child visit (procedure), http://snomed.info/sct}], Well child visit (procedure)}, 1, NULL}, {NULL, NULL, NULL, NULL, [1], NULL, {USD, 136.0}, NULL, {[{140, Influenza, seasonal, injectable, preservative free, http://hl7.org/fhir/sid/cvx}], Influenza, seasonal, injectable, preservative free}, 2, NULL}, {NULL, NULL, NULL, NULL, NULL, NULL, {USD, 471.37}, [1], {[{430193006, Medication Reconciliation (procedure), http://snomed.info/sct}], Medication Reconciliation (procedure)}, 3, NULL}]                                                                                                                                   |{Abdul218 Gusikowski974, urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1}|NULL                                           |[{{urn:uuid:fc73ae82-5e26-e35f-c75d-9e55f2d49d44}, 1}]|{CLSC J-OLIVIER-CAMIRAND, Organization?identifier=https://github.com/synthetichealth/synthea|8e9ecbd4-ae45-3256-93e7-95085fac346d}    |[{{[{info, http://terminology.hl7.org/CodeSystem/claiminformationcategory}]}, 1, {urn:uuid:7b2a9d9e-6033-ce5a-4e70-b04debe55b85}}]                                                                                                                                  |{"value":125.0,"currency":"USD"}  |{"coding":[{"system":"http://terminology.hl7.org/CodeSystem/claim-type","code":"institutional"}]}|
# |{1979-03-28T12:16:28-05:00, 1979-03-28T12:01:28-05:00}|1979-03-28T12:16:28-05:00|NULL                                                                                                                    |eb0ad4cb-8ddd-860f-108d-54ffa63ca174|[{NULL, NULL, NULL, [{urn:uuid:59887ae2-cc46-9a0d-3a70-a961addf2dff}], NULL, NULL, NULL, NULL, {[{410620009, Well child visit (procedure), http://snomed.info/sct}], Well child visit (procedure)}, 1, NULL}, {NULL, NULL, NULL, NULL, NULL, NULL, {USD, 336.7}, [1], {[{430193006, Medication Reconciliation (procedure), http://snomed.info/sct}], Medication Reconciliation (procedure)}, 2, NULL}]                                                                                                                                                                                                                                                                                                                                                      |{Abdul218 Gusikowski974, urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1}|NULL                                           |[{{urn:uuid:ba7caf04-a7ae-2040-751e-a194638dbdfc}, 1}]|{CLSC J-OLIVIER-CAMIRAND, Organization?identifier=https://github.com/synthetichealth/synthea|8e9ecbd4-ae45-3256-93e7-95085fac346d}    |NULL                                                                                                                                                                                                                                                                |{"value":125.0,"currency":"USD"}  |{"coding":[{"system":"http://terminology.hl7.org/CodeSystem/claim-type","code":"institutional"}]}|
# |{1979-09-26T13:16:28-04:00, 1979-09-26T13:01:28-04:00}|1979-09-26T13:16:28-04:00|NULL                                                                                                                    |23255668-7444-ca8a-5057-e3b483f8d0f7|[{NULL, NULL, NULL, [{urn:uuid:27f8e3ce-76b7-60cc-29aa-c6f6984b2ab8}], NULL, NULL, NULL, NULL, {[{410620009, Well child visit (procedure), http://snomed.info/sct}], Well child visit (procedure)}, 1, NULL}, {NULL, NULL, NULL, NULL, [1], NULL, {USD, 136.0}, NULL, {[{140, Influenza, seasonal, injectable, preservative free, http://hl7.org/fhir/sid/cvx}], Influenza, seasonal, injectable, preservative free}, 2, NULL}]                                                                                                                                                                                                                                                                                                                             |{Abdul218 Gusikowski974, urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1}|NULL                                           |NULL                                                  |{CLSC J-OLIVIER-CAMIRAND, Organization?identifier=https://github.com/synthetichealth/synthea|8e9ecbd4-ae45-3256-93e7-95085fac346d}    |[{{[{info, http://terminology.hl7.org/CodeSystem/claiminformationcategory}]}, 1, {urn:uuid:475b9b26-97dd-61f0-53c6-1e3daa5564bf}}]                                                                                                                                  |{"value":125.0,"currency":"USD"}  |{"coding":[{"system":"http://terminology.hl7.org/CodeSystem/claim-type","code":"institutional"}]}|
# |{1979-10-11T08:16:28-04:00, 1979-10-11T08:01:28-04:00}|1979-10-11T08:16:28-04:00|[{{urn:uuid:a1580e3b-21b0-9b84-dee0-a0518ed84367}, 1, NULL}]                                                            |5c6fb96d-8d11-0d11-6b84-268664cb2e98|[{NULL, NULL, NULL, [{urn:uuid:b355464c-dafc-5c17-f72d-03c3fdedbe35}], NULL, NULL, NULL, NULL, {[{185345009, Encounter for symptom, http://snomed.info/sct}], Encounter for symptom}, 1, NULL}, {NULL, NULL, [1], NULL, NULL, NULL, NULL, NULL, {[{444814009, Viral sinusitis (disorder), http://snomed.info/sct}], Viral sinusitis (disorder)}, 2, NULL}]                                                                                                                                                                                                                                                                                                                                                                                                  |{Abdul218 Gusikowski974, urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1}|NULL                                           |NULL                                                  |{HФPITAL ET CHSLD D'YOUVILLE, Organization?identifier=https://github.com/synthetichealth/synthea|6eb4830c-08de-3127-9453-f76bb44f3f0e}|NULL                                                                                                                                                                                                                                                                |{"value":75.0,"currency":"USD"}   |{"coding":[{"system":"http://terminology.hl7.org/CodeSystem/claim-type","code":"institutional"}]}|
# |{1980-05-16T15:25:49-04:00, 1980-05-16T13:01:28-04:00}|1980-05-16T15:25:49-04:00|NULL                                                                                                                    |1cbf7a9f-c924-aaaf-d947-a4f3f7c799d3|[{NULL, NULL, NULL, [{urn:uuid:fece2c29-2b42-3bee-1149-0b764feb883c}], NULL, NULL, NULL, NULL, {[{50849002, Emergency Room Admission, http://snomed.info/sct}], Emergency Room Admission}, 1, NULL}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |{NULL, urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1}                  |{urn:uuid:ea4c8a11-de94-dc85-157b-58818c7d612c}|NULL                                                  |{HФPITAL ET CHSLD D'YOUVILLE, Organization?identifier=https://github.com/synthetichealth/synthea|6eb4830c-08de-3127-9453-f76bb44f3f0e}|NULL                                                                                                                                                                                                                                                                |{"value":1011.86,"currency":"USD"}|{"coding":[{"system":"http://terminology.hl7.org/CodeSystem/claim-type","code":"pharmacy"}]}     |
# |{1980-05-16T15:25:49-04:00, 1980-05-16T13:01:28-04:00}|1980-05-16T15:25:49-04:00|[{{urn:uuid:a4060b03-c64c-43fb-876d-384224eefded}, 1, NULL}, {{urn:uuid:786b2b31-edfe-b2ea-cd9a-6c7ea1520ca1}, 2, NULL}]|038de9a3-3d85-0801-8e65-5dd474d2a7a5|[{NULL, NULL, NULL, [{urn:uuid:fece2c29-2b42-3bee-1149-0b764feb883c}], NULL, NULL, NULL, NULL, {[{50849002, Emergency Room Admission, http://snomed.info/sct}], Emergency Room Admission}, 1, NULL}, {NULL, NULL, [1], NULL, NULL, NULL, NULL, NULL, {[{128613002, Seizure disorder, http://snomed.info/sct}], Seizure disorder}, 2, NULL}, {NULL, NULL, [2], NULL, NULL, NULL, NULL, NULL, {[{703151001, History of single seizure (situation), http://snomed.info/sct}], History of single seizure (situation)}, 3, NULL}, {NULL, NULL, NULL, NULL, NULL, NULL, {USD, 8249.73}, [1], {[{54550000, Seizure Count Cerebral Cortex Electroencephalogram (EEG), http://snomed.info/sct}], Seizure Count Cerebral Cortex Electroencephalogram (EEG)}, 4, NULL}]|{Abdul218 Gusikowski974, urn:uuid:9a9ab84b-7e52-c718-c9ff-9b0c5dea86b1}|NULL                                           |[{{urn:uuid:2c477048-9d97-5bf6-64ca-4de470a225b5}, 1}]|{HФPITAL ET CHSLD D'YOUVILLE, Organization?identifier=https://github.com/synthetichealth/synthea|6eb4830c-08de-3127-9453-f76bb44f3f0e}|NULL                                                                                                                                                                                                                                                                |{"value":125.0,"currency":"USD"}  |{"coding":[{"system":"http://terminology.hl7.org/CodeSystem/claim-type","code":"institutional"}]}|
# +------------------------------------------------------+-------------------------+------------------------------------------------------------------------------------------------------------------------+------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------+-----------------------------------------------+------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------------------------+-------------------------------------------------------------------------------------------------+
# only showing top 20 rows
#
# Resource: Condition
# All Columns: ['abatementDateTime', 'address', 'authoredOn', 'billablePeriod', 'birthDate', 'careTeam', 'category', 'claim', 'class', 'clinicalStatus', 'code', 'communication', 'component', 'contained', 'created', 'deceasedDateTime', 'diagnosis', 'effectiveDateTime', 'encounter', 'extension', 'gender', 'hospitalization', 'id', 'identifier', 'insurance', 'insurer', 'intent', 'issued', 'item', 'maritalStatus', 'medicationCodeableConcept', 'multipleBirthBoolean', 'name', 'occurrenceDateTime', 'onsetDateTime', 'outcome', 'participant', 'patient', 'payment', 'performedPeriod', 'period', 'prescription', 'primarySource', 'priority', 'procedure', 'provider', 'reasonCode', 'reasonReference', 'recordedDate', 'referral', 'requester', 'resourceType', 'result', 'serviceProvider', 'status', 'subject', 'supportingInfo', 'telecom', 'text', 'total', 'type', 'use', 'vaccineCode', 'valueCodeableConcept', 'valueQuantity', 'verificationStatus']
# Non-Null Columns: ['abatementDateTime', 'clinicalStatus', 'code', 'encounter', 'id', 'onsetDateTime', 'recordedDate']
# DataFrame with Non-Null Columns for Condition:
# +-------------------------+------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------+-----------------------------------------------+------------------------------------+-------------------------+-------------------------+
# |abatementDateTime        |clinicalStatus                                                          |code                                                                                                                 |encounter                                      |id                                  |onsetDateTime            |recordedDate             |
# +-------------------------+------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------+-----------------------------------------------+------------------------------------+-------------------------+-------------------------+
# |1977-06-25T18:01:28-04:00|{[{resolved, http://terminology.hl7.org/CodeSystem/condition-clinical}]}|{[{43878008, Streptococcal sore throat (disorder), http://snomed.info/sct}], Streptococcal sore throat (disorder)}   |{urn:uuid:1e163045-e37f-c8eb-9a9b-9d3e86b0dbf9}|536764fb-309c-373f-dcdf-36eb0889f849|1977-06-15T01:01:28-04:00|1977-06-15T01:01:28-04:00|
# |1979-11-01T07:01:28-05:00|{[{resolved, http://terminology.hl7.org/CodeSystem/condition-clinical}]}|{[{444814009, Viral sinusitis (disorder), http://snomed.info/sct}], Viral sinusitis (disorder)}                      |{urn:uuid:b355464c-dafc-5c17-f72d-03c3fdedbe35}|a1580e3b-21b0-9b84-dee0-a0518ed84367|1979-10-11T08:01:28-04:00|1979-10-11T08:01:28-04:00|
# |NULL                     |{[{active, http://terminology.hl7.org/CodeSystem/condition-clinical}]}  |{[{128613002, Seizure disorder, http://snomed.info/sct}], Seizure disorder}                                          |{urn:uuid:fece2c29-2b42-3bee-1149-0b764feb883c}|a4060b03-c64c-43fb-876d-384224eefded|1980-05-16T13:01:28-04:00|1980-05-16T13:01:28-04:00|
# |NULL                     |{[{active, http://terminology.hl7.org/CodeSystem/condition-clinical}]}  |{[{703151001, History of single seizure (situation), http://snomed.info/sct}], History of single seizure (situation)}|{urn:uuid:fece2c29-2b42-3bee-1149-0b764feb883c}|786b2b31-edfe-b2ea-cd9a-6c7ea1520ca1|1980-05-16T13:01:28-04:00|1980-05-16T13:01:28-04:00|
# |1983-09-05T09:01:28-04:00|{[{resolved, http://terminology.hl7.org/CodeSystem/condition-clinical}]}|{[{195662009, Acute viral pharyngitis (disorder), http://snomed.info/sct}], Acute viral pharyngitis (disorder)}      |{urn:uuid:34526c88-9d36-a13b-a83e-ea0984c02bf5}|c4d75f26-1a0b-a00a-832c-172dae16763d|1983-08-26T07:01:28-04:00|1983-08-26T07:01:28-04:00|
# +-------------------------+------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------+-----------------------------------------------+------------------------------------+-------------------------+-------------------------+
#
# Resource: DiagnosticReport
# ...
# |[{[{laboratory, laboratory, http://terminology.hl7.org/CodeSystem/observation-category}]}]  |{[{787-2, MCV [Entitic volume] by Automated count, http://loinc.org}], MCV [Entitic volume] by Automated count}                                                                    |NULL                                                                                                                                                                                                                                                                         |1975-10-22T13:01:28-04:00|{urn:uuid:bfc04826-0c53-f1b6-cdb2-6a49dba3402e}|e94a450f-6a80-d20a-cbbb-e8781e42bedf|1975-10-22T13:01:28.299-04:00|NULL                                                               |{fL, http://unitsofmeasure.org, fL, 93.98}           |
# |[{[{laboratory, laboratory, http://terminology.hl7.org/CodeSystem/observation-category}]}]  |{[{785-6, MCH [Entitic mass] by Automated count, http://loinc.org}], MCH [Entitic mass] by Automated count}                                                                        |NULL                                                                                                                                                                                                                                                                         |1975-10-22T13:01:28-04:00|{urn:uuid:bfc04826-0c53-f1b6-cdb2-6a49dba3402e}|6ee4b1b4-1939-d7e9-1868-a4dc9d56fb13|1975-10-22T13:01:28.299-04:00|NULL                                                               |{pg, http://unitsofmeasure.org, pg, 27.183}          |
# |[{[{laboratory, laboratory, http://terminology.hl7.org/CodeSystem/observation-category}]}]  |{[{786-4, MCHC [Mass/volume] by Automated count, http://loinc.org}], MCHC [Mass/volume] by Automated count}                                                                        |NULL                                                                                                                                                                                                                                                                         |1975-10-22T13:01:28-04:00|{urn:uuid:bfc04826-0c53-f1b6-cdb2-6a49dba3402e}|9fff2476-bf23-5110-1569-00f0ab9be9f0|1975-10-22T13:01:28.299-04:00|NULL                                                               |{g/dL, http://unitsofmeasure.org, g/dL, 34.553}      |
# |[{[{laboratory, laboratory, http://terminology.hl7.org/CodeSystem/observation-category}]}]  |{[{21000-5, Erythrocyte distribution width [Entitic volume] by Automated count, http://loinc.org}], Erythrocyte distribution width [Entitic volume] by Automated count}            |NULL                                                                                                                                                                                                                                                                         |1975-10-22T13:01:28-04:00|{urn:uuid:bfc04826-0c53-f1b6-cdb2-6a49dba3402e}|8403abc7-a17e-f866-0414-cea947c5ba5c|1975-10-22T13:01:28.299-04:00|NULL                                                               |{fL, http://unitsofmeasure.org, fL, 42.518}          |
# |[{[{laboratory, laboratory, http://terminology.hl7.org/CodeSystem/observation-category}]}]  |{[{777-3, Platelets [#/volume] in Blood by Automated count, http://loinc.org}], Platelets [#/volume] in Blood by Automated count}                                                  |NULL                                                                                                                                                                                                                                                                         |1975-10-22T13:01:28-04:00|{urn:uuid:bfc04826-0c53-f1b6-cdb2-6a49dba3402e}|a07e740b-ec96-a1bf-e3e5-be11f96c0ea9|1975-10-22T13:01:28.299-04:00|NULL                                                               |{10*3/uL, http://unitsofmeasure.org, 10*3/uL, 254.24}|
# |[{[{laboratory, laboratory, http://terminology.hl7.org/CodeSystem/observation-category}]}]  |{[{32207-3, Platelet distribution width [Entitic volume] in Blood by Automated count, http://loinc.org}], Platelet distribution width [Entitic volume] in Blood by Automated count}|NULL                                                                                                                                                                                                                                                                         |1975-10-22T13:01:28-04:00|{urn:uuid:bfc04826-0c53-f1b6-cdb2-6a49dba3402e}|6b44a9b2-ffd8-745d-a0be-df81e46724ad|1975-10-22T13:01:28.299-04:00|NULL                                                               |{fL, http://unitsofmeasure.org, fL, 419.32}          |
# |[{[{laboratory, laboratory, http://terminology.hl7.org/CodeSystem/observation-category}]}]  |{[{32623-1, Platelet mean volume [Entitic volume] in Blood by Automated count, http://loinc.org}], Platelet mean volume [Entitic volume] in Blood by Automated count}              |NULL                                                                                                                                                                                                                                                                         |1975-10-22T13:01:28-04:00|{urn:uuid:bfc04826-0c53-f1b6-cdb2-6a49dba3402e}|745ee88a-601d-c9b9-3bed-95114614dc32|1975-10-22T13:01:28.299-04:00|NULL                                                               |{fL, http://unitsofmeasure.org, fL, 11.606}          |
# |[{[{survey, survey, http://terminology.hl7.org/CodeSystem/observation-category}]}]          |{[{72166-2, Tobacco smoking status NHIS, http://loinc.org}], Tobacco smoking status NHIS}                                                                                          |NULL                                                                                                                                                                                                                                                                         |1975-10-22T13:01:28-04:00|{urn:uuid:bfc04826-0c53-f1b6-cdb2-6a49dba3402e}|5c5acc4c-80ba-b483-4ac3-a746f97d3f91|1975-10-22T13:01:28.299-04:00|{[{266919005, Never smoker, http://snomed.info/sct}], Never smoker}|NULL                                                 |
# +--------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------+-----------------------------------------------+------------------------------------+-----------------------------+-------------------------------------------------------------------+-----------------------------------------------------+
# only showing top 20 rows
#
# Resource: Patient
# All Columns: ['abatementDateTime', 'address', 'authoredOn', 'billablePeriod', 'birthDate', 'careTeam', 'category', 'claim', 'class', 'clinicalStatus', 'code', 'communication', 'component', 'contained', 'created', 'deceasedDateTime', 'diagnosis', 'effectiveDateTime', 'encounter', 'extension', 'gender', 'hospitalization', 'id', 'identifier', 'insurance', 'insurer', 'intent', 'issued', 'item', 'maritalStatus', 'medicationCodeableConcept', 'multipleBirthBoolean', 'name', 'occurrenceDateTime', 'onsetDateTime', 'outcome', 'participant', 'patient', 'payment', 'performedPeriod', 'period', 'prescription', 'primarySource', 'priority', 'procedure', 'provider', 'reasonCode', 'reasonReference', 'recordedDate', 'referral', 'requester', 'resourceType', 'result', 'serviceProvider', 'status', 'subject', 'supportingInfo', 'telecom', 'text', 'total', 'type', 'use', 'vaccineCode', 'valueCodeableConcept', 'valueQuantity', 'verificationStatus']
# Non-Null Columns: []
# DataFrame with Non-Null Columns for Patient:
# ++
# ||
# ++
# ||
# ++
#
# Resource: Procedure
# All Columns: ['abatementDateTime', 'address', 'authoredOn', 'billablePeriod', 'birthDate', 'careTeam', 'category', 'claim', 'class', 'clinicalStatus', 'code', 'communication', 'component', 'contained', 'created', 'deceasedDateTime', 'diagnosis', 'effectiveDateTime', 'encounter', 'extension', 'gender', 'hospitalization', 'id', 'identifier', 'insurance', 'insurer', 'intent', 'issued', 'item', 'maritalStatus', 'medicationCodeableConcept', 'multipleBirthBoolean', 'name', 'occurrenceDateTime', 'onsetDateTime', 'outcome', 'participant', 'patient', 'payment', 'performedPeriod', 'period', 'prescription', 'primarySource', 'priority', 'procedure', 'provider', 'reasonCode', 'reasonReference', 'recordedDate', 'referral', 'requester', 'resourceType', 'result', 'serviceProvider', 'status', 'subject', 'supportingInfo', 'telecom', 'text', 'total', 'type', 'use', 'vaccineCode', 'valueCodeableConcept', 'valueQuantity', 'verificationStatus']
# Non-Null Columns: ['code', 'encounter', 'id', 'performedPeriod', 'reasonReference']
# DataFrame with Non-Null Columns for Procedure:
# +----------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------+------------------------------------+------------------------------------------------------+-------------------------------------------------------------------------------------+
# |code                                                                                                                                                      |encounter                                      |id                                  |performedPeriod                                       |reasonReference                                                                      |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------+------------------------------------+------------------------------------------------------+-------------------------------------------------------------------------------------+
# |{[{430193006, Medication Reconciliation (procedure), http://snomed.info/sct}], Medication Reconciliation (procedure)}                                     |{urn:uuid:bfc04826-0c53-f1b6-cdb2-6a49dba3402e}|19cc767f-f150-73e8-c771-711584a47298|{1975-10-22T13:16:28-04:00, 1975-10-22T13:01:28-04:00}|NULL                                                                                 |
# |{[{430193006, Medication Reconciliation (procedure), http://snomed.info/sct}], Medication Reconciliation (procedure)}                                     |{urn:uuid:808b2737-7039-9fcf-d26a-c199c8db91a0}|c8d99769-583c-3d68-f7d0-c0673ac17d8d|{1975-11-26T12:16:28-05:00, 1975-11-26T12:01:28-05:00}|NULL                                                                                 |
# |{[{430193006, Medication Reconciliation (procedure), http://snomed.info/sct}], Medication Reconciliation (procedure)}                                     |{urn:uuid:5095c5d9-cb41-8170-4004-ead0ca55059b}|f239e469-387d-8b23-ccc4-eff873a1a321|{1976-03-31T12:16:28-05:00, 1976-03-31T12:01:28-05:00}|NULL                                                                                 |
# |{[{430193006, Medication Reconciliation (procedure), http://snomed.info/sct}], Medication Reconciliation (procedure)}                                     |{urn:uuid:b0fff8cf-34ab-9025-82d5-f6fc4bdfdddc}|3d40f44f-45d5-3d8c-5fdb-a1b029d6cd8a|{1976-06-30T13:16:28-04:00, 1976-06-30T13:01:28-04:00}|NULL                                                                                 |
# |{[{430193006, Medication Reconciliation (procedure), http://snomed.info/sct}], Medication Reconciliation (procedure)}                                     |{urn:uuid:07a09621-f89c-17a2-4db1-574f32c74256}|c03f340b-0062-327f-361f-896275ee3b04|{1976-09-29T13:16:28-04:00, 1976-09-29T13:01:28-04:00}|NULL                                                                                 |
# |{[{430193006, Medication Reconciliation (procedure), http://snomed.info/sct}], Medication Reconciliation (procedure)}                                     |{urn:uuid:aa91b6c4-62c8-26be-6dfd-53e8393f1297}|1c2f7ae5-fe0c-2411-8a0e-0431e403d17d|{1978-03-29T12:16:28-05:00, 1978-03-29T12:01:28-05:00}|NULL                                                                                 |
# |{[{430193006, Medication Reconciliation (procedure), http://snomed.info/sct}], Medication Reconciliation (procedure)}                                     |{urn:uuid:68271ae7-f0dd-3240-1d0f-c2dbab073c6f}|fc73ae82-5e26-e35f-c75d-9e55f2d49d44|{1978-09-27T13:16:28-04:00, 1978-09-27T13:01:28-04:00}|NULL                                                                                 |
# |{[{430193006, Medication Reconciliation (procedure), http://snomed.info/sct}], Medication Reconciliation (procedure)}                                     |{urn:uuid:59887ae2-cc46-9a0d-3a70-a961addf2dff}|ba7caf04-a7ae-2040-751e-a194638dbdfc|{1979-03-28T12:16:28-05:00, 1979-03-28T12:01:28-05:00}|NULL                                                                                 |
# |{[{54550000, Seizure Count Cerebral Cortex Electroencephalogram (EEG), http://snomed.info/sct}], Seizure Count Cerebral Cortex Electroencephalogram (EEG)}|{urn:uuid:fece2c29-2b42-3bee-1149-0b764feb883c}|2c477048-9d97-5bf6-64ca-4de470a225b5|{1980-05-16T15:25:49-04:00, 1980-05-16T13:01:28-04:00}|NULL                                                                                 |
# |{[{430193006, Medication Reconciliation (procedure), http://snomed.info/sct}], Medication Reconciliation (procedure)}                                     |{urn:uuid:14f606cf-f3ae-94d6-2c42-d2f436dd4a62}|fbca7002-ea27-3b27-ae11-610b2acbe0a1|{1981-10-07T13:16:28-04:00, 1981-10-07T13:01:28-04:00}|NULL                                                                                 |
# |{[{54550000, Seizure Count Cerebral Cortex Electroencephalogram (EEG), http://snomed.info/sct}], Seizure Count Cerebral Cortex Electroencephalogram (EEG)}|{urn:uuid:84f8952a-6714-81ee-0b09-ddf7f5d7f49b}|126a54dc-81b0-7925-e888-a2826824e790|{1982-03-22T14:12:04-05:00, 1982-03-22T12:01:28-05:00}|NULL                                                                                 |
# |{[{117015009, Throat culture (procedure), http://snomed.info/sct}], Throat culture (procedure)}                                                           |{urn:uuid:34526c88-9d36-a13b-a83e-ea0984c02bf5}|81ee0b01-3e83-29c6-d620-97162738f0f4|{1983-08-26T07:16:28-04:00, 1983-08-26T07:01:28-04:00}|[{Acute viral pharyngitis (disorder), urn:uuid:c4d75f26-1a0b-a00a-832c-172dae16763d}]|
# +----------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------+------------------------------------+------------------------------------------------------+-------------------------------------------------------------------------------------+
